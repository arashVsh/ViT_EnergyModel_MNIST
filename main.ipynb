# %% [markdown]
# # Tutorial 8: Deep Energy-Based Generative Models
#
# ![Status](https://img.shields.io/static/v1.svg?label=Status&message=Finished&color=green)
#
# **Filled notebook:**
# [![View on Github](https://img.shields.io/static/v1.svg?logo=github&label=Repo&message=View%20On%20Github&color=lightgrey)](https://github.com/phlippe/uvadlc_notebooks/blob/master/docs/tutorial_notebooks/tutorial8/Deep_Energy_Models.ipynb)
# [![Open In Collab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/phlippe/uvadlc_notebooks/blob/master/docs/tutorial_notebooks/tutorial8/Deep_Energy_Models.ipynb)
# **Pre-trained models:**
# [![View files on Github](https://img.shields.io/static/v1.svg?logo=github&label=Repo&message=View%20On%20Github&color=lightgrey)](https://github.com/phlippe/saved_models/tree/main/tutorial8)
# [![GoogleDrive](https://img.shields.io/static/v1.svg?logo=google-drive&logoColor=yellow&label=GDrive&message=Download&color=yellow)](https://drive.google.com/drive/folders/11ZI7x2sfCNtaZUNpe4v08YXWN870spXs?usp=sharing)
# **Recordings:**
# [![YouTube - Part 1](https://img.shields.io/static/v1.svg?logo=youtube&label=YouTube&message=Part%201&color=red)](https://youtu.be/E6PDwquBBQc)
# [![YouTube - Part 2](https://img.shields.io/static/v1.svg?logo=youtube&label=YouTube&message=Part%202&color=red)](https://youtu.be/QJ94zuSQoP4)
# **Author:** Phillip Lippe

# %% [markdown]
# ## Load Libraries

# %%
from Classifier.Evaluation import evaluate
from DataHandlers.DataLoading import loadOriginalTrainSet, loadTestSet, loadGeneratedSet

## PyTorch
import torch
from DataHandlers.DetailsDisplayer import detailsDisplayer
from ShowImages import showImages

# %% [markdown]
# ## Choice of data

# %%
USE_ORIGINAL_DATA = False # If false, the classifier gets trained only on the generated set

# %% [markdown]
# ## Used Device

# %%
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print("Device:", device)
# Out:
# Device: cuda:0

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Load test loader

# %%
test_loader = loadTestSet()
detailsDisplayer(test_loader)
# Out:
# Batch Size: 256
# Number of Batches: 40
# Total Samples: 10000
# Samples per class:
# Class 0: 980 samples
# Class 1: 1135 samples
# Class 2: 1032 samples
# Class 3: 1010 samples
# Class 4: 982 samples
# Class 5: 892 samples
# Class 6: 958 samples
# Class 7: 1028 samples
# Class 8: 974 samples
# Class 9: 1009 samples

# %% [markdown]
# ### Load train loader

# %%
if USE_ORIGINAL_DATA:
    train_loader = loadOriginalTrainSet()
    print('Using the original train set')
else:
    train_loader = loadGeneratedSet()
    print('Using the generated set')

detailsDisplayer(train_loader)
# Out:
# Using the generated set
# Batch Size: 128
# Number of Batches: 468
# Total Samples: 60000
# Samples per class:
# Class 0: 5923 samples
# Class 1: 6742 samples
# Class 2: 5958 samples
# Class 3: 6131 samples
# Class 4: 5842 samples
# Class 5: 5421 samples
# Class 6: 5918 samples
# Class 7: 6265 samples
# Class 8: 5851 samples
# Class 9: 5949 samples

# %% [markdown]
# ## Display train images

# %%
showImages(train_loader.dataset, "Generated Images")

# %% [markdown]
# ## Classify

# %%
evaluate(train_loader, test_loader, device)
# Out:
# c:\Projects\MNIST_ViT_EnergyModel\.venv\Lib\site-packages\torch\nn\modules\transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# c:\Projects\MNIST_ViT_EnergyModel\.venv\Lib\site-packages\torch\nn\functional.py:5476: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# Epoch [1/30], Train Loss: 2.1625, Test Loss: 1.9966
# Epoch [2/30], Train Loss: 1.8281, Test Loss: 1.7340
# Epoch [3/30], Train Loss: 1.5510, Test Loss: 1.4850
# Epoch [4/30], Train Loss: 1.3045, Test Loss: 1.2664
# Epoch [5/30], Train Loss: 1.0955, Test Loss: 1.0922
# Epoch [6/30], Train Loss: 0.9239, Test Loss: 0.9658
# Epoch [7/30], Train Loss: 0.7835, Test Loss: 0.8523
# Epoch [8/30], Train Loss: 0.6765, Test Loss: 0.7726
# Epoch [9/30], Train Loss: 0.5845, Test Loss: 0.6865
# Epoch [10/30], Train Loss: 0.5112, Test Loss: 0.6850
# Epoch [11/30], Train Loss: 0.4505, Test Loss: 0.5787
# Epoch [12/30], Train Loss: 0.3990, Test Loss: 0.5531
# Epoch [13/30], Train Loss: 0.3589, Test Loss: 0.5440
# Epoch [14/30], Train Loss: 0.3238, Test Loss: 0.5018
# Epoch [15/30], Train Loss: 0.2973, Test Loss: 0.4620
# Epoch [16/30], Train Loss: 0.2683, Test Loss: 0.4619
# Epoch [17/30], Train Loss: 0.2464, Test Loss: 0.4449
# Epoch [18/30], Train Loss: 0.2302, Test Loss: 0.4241
# Epoch [19/30], Train Loss: 0.2130, Test Loss: 0.3933
# Epoch [20/30], Train Loss: 0.1996, Test Loss: 0.3926
# Epoch [21/30], Train Loss: 0.1863, Test Loss: 0.3791
# Epoch [22/30], Train Loss: 0.1755, Test Loss: 0.3817
# Epoch [23/30], Train Loss: 0.1660, Test Loss: 0.3697
# Epoch [24/30], Train Loss: 0.1560, Test Loss: 0.3734
# Epoch [25/30], Train Loss: 0.1497, Test Loss: 0.3714
# Epoch [26/30], Train Loss: 0.1397, Test Loss: 0.3843
# Epoch [27/30], Train Loss: 0.1331, Test Loss: 0.3421
# Epoch [28/30], Train Loss: 0.1280, Test Loss: 0.3482
# Epoch [29/30], Train Loss: 0.1193, Test Loss: 0.3282
# Epoch [30/30], Train Loss: 0.1155, Test Loss: 0.3450
# Total Test Accuracy: 89%
# Class 0 Test Accuracy: 94%
# Class 1 Test Accuracy: 97%
# Class 2 Test Accuracy: 87%
# Class 3 Test Accuracy: 84%
# Class 4 Test Accuracy: 83%
# Class 5 Test Accuracy: 78%
# Class 6 Test Accuracy: 95%
# Class 7 Test Accuracy: 93%
# Class 8 Test Accuracy: 87%
# Class 9 Test Accuracy: 87%

# %% [markdown]
# ---
#
# [![Star our repository](https://img.shields.io/static/v1.svg?logo=star&label=⭐&message=Star%20Our%20Repository&color=yellow)](https://github.com/phlippe/uvadlc_notebooks/)  If you found this tutorial helpful, consider ⭐-ing our repository.
# [![Ask questions](https://img.shields.io/static/v1.svg?logo=star&label=❔&message=Ask%20Questions&color=9cf)](https://github.com/phlippe/uvadlc_notebooks/issues)  For any questions, typos, or bugs that you found, please raise an issue on GitHub.
#
# ---
